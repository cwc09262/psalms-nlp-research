# %% [markdown]
# # Working through the Blind Scoring
#
# After taking the 8 quieres and running then through the four different queries from a previous notebook, I was able to blind score each result that was attached to one of the queries. I scored them on a scale of 0 - 10, with:
# - **0** – No semantic relationship
# - **1–3** – Minimal semantic overlap
# - **4–6** – Partial or contextual relevance
# - **7–9** – Strong semantic alignment
# - **10** – Exact or near-exact semantic match
#
# This notebook will now closely lopok my my blind scoring in a couple of different ways.

# %%
import pandas as pd

scores = pd.read_csv("results_scored.csv")

scores = scores.iloc[:, :-2]

# %%
scores
# Out:
#                              Query       Method  Similarity Score (%)  \
# 0       For the Peace of the world  TFIDF_GLoVe                 43.73
# 1       For the Peace of the world  TFIDF_GLoVe                 41.00
# 2       For the Peace of the world  TFIDF_GLoVe                 40.99
# 3       For the Peace of the world  TFIDF_GLoVe                 38.74
# 4       For the Peace of the world  TFIDF_GLoVe                 38.43
# ..                             ...          ...                   ...
# 187  Have mercy on me, O God, h...        TFIDF                 21.90
# 188  Have mercy on me, O God, h...        TFIDF                 21.33
# 189  Have mercy on me, O God, h...        TFIDF                 20.87
# 190  Have mercy on me, O God, h...        TFIDF                 19.55
# 191  Have mercy on me, O God, h...        TFIDF                 19.11
#
#         Text  Psalm Num                          Verse  HumanScore
# 0      Bible         92  1For the day before the Sa...        10.0
# 1    Psalter        121  I was glad because of them...         0.0
# 2      Bible        121  1An ode of ascents Iwas gl...         8.0
# 3      Bible        131  1An ode of ascents Remembe...         4.0
# 4      Bible         96  By David when His earth is...         9.0
# ..       ...        ...                            ...         ...
# 187  Psalter         39  I waited patiently for the...         9.0
# 188  Psalter         54  Give ear to my prayer, O G...         6.0
# 189  Psalter        142  Hear my prayer, O Lord; gi...         9.0
# 190  Psalter         68  Save me, O God, for the wa...         4.0
# 191  Psalter         70  In Thee, O Lord, have I pu...        10.0
#
# [192 rows x 7 columns]

# %% [markdown]
# Among the 8 queires, there are 4 different categories of queires and they are as followed.
#
# ## Querie Categories
# #### 1. Simple Keyword Queries
# - **Query 1:** mercy
#
# #### 2. Phrase/Exact Match Queries
# - **Query 2:** The Lord is my shepherd
#
# #### 3. Thematic/Semantic Queries
# - **Query 3:** protection from enemies
# - **Query 4:** praise in times of suffering
#
# #### 4. Long/Complex Queries
# - **Query 5:** How does the psalmist express trust in God while surrounded by fear and uncertainty?
# - **Query 6:** Verses where the psalmist remembers past deliverance and uses it to find hope in present trials.
#
# #### 5. Orthodox Service Quotes
# ##### From *Vespers*
# - **Query 7:**
#     >"Rejoice, O ye heavens, sound the trumpets, ye foundation of the earth, thunder forth gladness, O ye mountains: for behold, Emanuel to    the Cross our sins, and the Giver of Life hath slain death, rasing up Adam,; for He loveth man kind."
#
# - **Query 8:**
#     >"“Have mercy on me, O God, have mercy on me. For my soul trusts in Thee, and in the shadow of Thy wings will I hope, until iniquity pass away.”
#
# ##### From *"The Great Litany"*
# - **Query 9**
#     >"For the Peace of the world."
#
# We are going to be adding these query categories to the data itself before begining analysis. Building in this categorical variable, there is a further breakdown that can be done inorder to find results and conclusions.

# %%
QUERY_TO_CATEGORY = {
    "mercy": "Simple Keyword Queries",
    "The Lord is my shepherd": "Phrase/Exact Match Queries",
    "protection from enemies": "Thematic/Semantic Queries",
    "praise in times of suffering": "Thematic/Semantic Queries",
    "How does the psalmist express trust in God while surrounded by fear and uncertainty?":
        "Long/Complex Queries",
    "Verses where the psalmist remembers past deliverance and uses it to find hope in present trials.":
        "Long/Complex Queries",
    "Rejoice, O ye heavens, sound the trumpets, ye foundation of the earth, thunder forth gladness, O ye mountains: for behold, Emanuel to the Cross our sins, and the Giver of Life hath slain death, raising up Adam; for He loveth mankind.":
        "Orthodox Service Quotes",
    "Have mercy on me, O God, have mercy on me. For my soul trusts in Thee, and in the shadow of Thy wings will I hope, until iniquity pass away.":
        "Orthodox Service Quotes",
    "For the Peace of the world": "Orthodox Service Quotes"
}

# %%
scores["Query Category"] = scores["Query"].map(QUERY_TO_CATEGORY)
scores
# Out:
#                              Query       Method  Similarity Score (%)  \
# 0       For the Peace of the world  TFIDF_GLoVe                 43.73
# 1       For the Peace of the world  TFIDF_GLoVe                 41.00
# 2       For the Peace of the world  TFIDF_GLoVe                 40.99
# 3       For the Peace of the world  TFIDF_GLoVe                 38.74
# 4       For the Peace of the world  TFIDF_GLoVe                 38.43
# ..                             ...          ...                   ...
# 187  Have mercy on me, O God, h...        TFIDF                 21.90
# 188  Have mercy on me, O God, h...        TFIDF                 21.33
# 189  Have mercy on me, O God, h...        TFIDF                 20.87
# 190  Have mercy on me, O God, h...        TFIDF                 19.55
# 191  Have mercy on me, O God, h...        TFIDF                 19.11
#
#         Text  Psalm Num                          Verse  HumanScore  \
# 0      Bible         92  1For the day before the Sa...        10.0
# 1    Psalter        121  I was glad because of them...         0.0
# 2      Bible        121  1An ode of ascents Iwas gl...         8.0
# 3      Bible        131  1An ode of ascents Remembe...         4.0
# 4      Bible         96  By David when His earth is...         9.0
# ..       ...        ...                            ...         ...
# 187  Psalter         39  I waited patiently for the...         9.0
# 188  Psalter         54  Give ear to my prayer, O G...         6.0
# 189  Psalter        142  Hear my prayer, O Lord; gi...         9.0
# 190  Psalter         68  Save me, O God, for the wa...         4.0
# 191  Psalter         70  In Thee, O Lord, have I pu...        10.0
#
#               Query Category
# 0    Orthodox Service Quotes
# 1    Orthodox Service Quotes
# 2    Orthodox Service Quotes
# 3    Orthodox Service Quotes
# 4    Orthodox Service Quotes
# ..                       ...
# 187  Orthodox Service Quotes
# 188  Orthodox Service Quotes
# 189  Orthodox Service Quotes
# 190  Orthodox Service Quotes
# 191  Orthodox Service Quotes
#
# [192 rows x 8 columns]

# %%
# reordering the columns of the dataframe
scores = scores [["Query", "Query Category", "Method", "Text", "Psalm Num", 
                  "Verse", "HumanScore", "Similarity Score (%)"]]

scores
# Out:
#                              Query           Query Category       Method  \
# 0       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 1       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 2       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 3       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 4       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# ..                             ...                      ...          ...
# 187  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 188  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 189  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 190  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 191  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
#
#         Text  Psalm Num                          Verse  HumanScore  \
# 0      Bible         92  1For the day before the Sa...        10.0
# 1    Psalter        121  I was glad because of them...         0.0
# 2      Bible        121  1An ode of ascents Iwas gl...         8.0
# 3      Bible        131  1An ode of ascents Remembe...         4.0
# 4      Bible         96  By David when His earth is...         9.0
# ..       ...        ...                            ...         ...
# 187  Psalter         39  I waited patiently for the...         9.0
# 188  Psalter         54  Give ear to my prayer, O G...         6.0
# 189  Psalter        142  Hear my prayer, O Lord; gi...         9.0
# 190  Psalter         68  Save me, O God, for the wa...         4.0
# 191  Psalter         70  In Thee, O Lord, have I pu...        10.0
#
#      Similarity Score (%)
# 0                   43.73
# 1                   41.00
# 2                   40.99
# 3                   38.74
# 4                   38.43
# ..                    ...
# 187                 21.90
# 188                 21.33
# 189                 20.87
# 190                 19.55
# 191                 19.11
#
# [192 rows x 8 columns]

# %% [markdown]
# ## Numbering the Results
# I also want to be able to reference the order of the results within each search. I collected the top 5 results from each search. There was a bug in my code that took the top 6 results from searches. I am going to just worry about the top 5 results to keep everything fair.

# %%
# temporary dataframe to not break the original 
temp = scores.copy()

# aqdding a column to number the indivudal results
temp['numbered_result'] = pd.NA
temp
# Out:
#                              Query           Query Category       Method  \
# 0       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 1       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 2       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 3       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 4       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# ..                             ...                      ...          ...
# 187  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 188  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 189  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 190  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 191  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
#
#         Text  Psalm Num                          Verse  HumanScore  \
# 0      Bible         92  1For the day before the Sa...        10.0
# 1    Psalter        121  I was glad because of them...         0.0
# 2      Bible        121  1An ode of ascents Iwas gl...         8.0
# 3      Bible        131  1An ode of ascents Remembe...         4.0
# 4      Bible         96  By David when His earth is...         9.0
# ..       ...        ...                            ...         ...
# 187  Psalter         39  I waited patiently for the...         9.0
# 188  Psalter         54  Give ear to my prayer, O G...         6.0
# 189  Psalter        142  Hear my prayer, O Lord; gi...         9.0
# 190  Psalter         68  Save me, O God, for the wa...         4.0
# 191  Psalter         70  In Thee, O Lord, have I pu...        10.0
#
#      Similarity Score (%) numbered_result
# 0                   43.73             NaN
# 1                   41.00             NaN
# 2                   40.99             NaN
# 3                   38.74             NaN
# 4                   38.43             NaN
# ..                    ...             ...
# 187                 21.90             NaN
# 188                 21.33             NaN
# 189                 20.87             NaN
# 190                 19.55             NaN
# 191                 19.11             NaN
#
# [192 rows x 9 columns]

# %%
n = temp.shape[0]

# starting with the number 1 result of a query
num_result = 1

query = temp["Query"].iloc[0]
method = temp["Method"].iloc[0]

for i in range(n):
    # checking if we are in the same group fo data to be numbered
    if query == temp["Query"].iloc[i] and method == temp["Method"].iloc[i]:
        temp["numbered_result"].iloc[i] = num_result
        num_result += 1
        
    # in an new group of results
    else:
        # the current result is the number result for the new set of results
        temp["numbered_result"].iloc[i] = 1
        # reset the number result
        num_result = 2
        # update to the new target query & method
        query = temp["Query"].iloc[i]
        method = temp["Method"].iloc[i]
# Out:
# /tmp/ipykernel_101/3907079077.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["numbered_result"].iloc[i] = num_result
# /tmp/ipykernel_101/3907079077.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["numbered_result"].iloc[i] = 1

# %%
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_colwidth", 30)

#temp.head(100)

# %%
pd.set_option("display.max_rows", 20)

# %%
# updating the original dataframe with the numbered results
scores = temp
scores
# Out:
#                              Query           Query Category       Method  \
# 0       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 1       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 2       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 3       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 4       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# ..                             ...                      ...          ...
# 187  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 188  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 189  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 190  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 191  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
#
#         Text  Psalm Num                          Verse  HumanScore  \
# 0      Bible         92  1For the day before the Sa...        10.0
# 1    Psalter        121  I was glad because of them...         0.0
# 2      Bible        121  1An ode of ascents Iwas gl...         8.0
# 3      Bible        131  1An ode of ascents Remembe...         4.0
# 4      Bible         96  By David when His earth is...         9.0
# ..       ...        ...                            ...         ...
# 187  Psalter         39  I waited patiently for the...         9.0
# 188  Psalter         54  Give ear to my prayer, O G...         6.0
# 189  Psalter        142  Hear my prayer, O Lord; gi...         9.0
# 190  Psalter         68  Save me, O God, for the wa...         4.0
# 191  Psalter         70  In Thee, O Lord, have I pu...        10.0
#
#      Similarity Score (%) numbered_result
# 0                   43.73               1
# 1                   41.00               2
# 2                   40.99               3
# 3                   38.74               4
# 4                   38.43               5
# ..                    ...             ...
# 187                 21.90               2
# 188                 21.33               3
# 189                 20.87               4
# 190                 19.55               5
# 191                 19.11               6
#
# [192 rows x 9 columns]

# %%
# reordering the columns
scores = scores [["Query", "Query Category", "Method", "numbered_result", "Text", "Psalm Num", 
                  "Verse", "HumanScore", "Similarity Score (%)"]]
scores
# Out:
#                              Query           Query Category       Method  \
# 0       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 1       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 2       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 3       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# 4       For the Peace of the world  Orthodox Service Quotes  TFIDF_GLoVe
# ..                             ...                      ...          ...
# 187  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 188  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 189  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 190  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 191  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
#
#     numbered_result     Text  Psalm Num                          Verse  \
# 0                 1    Bible         92  1For the day before the Sa...
# 1                 2  Psalter        121  I was glad because of them...
# 2                 3    Bible        121  1An ode of ascents Iwas gl...
# 3                 4    Bible        131  1An ode of ascents Remembe...
# 4                 5    Bible         96  By David when His earth is...
# ..              ...      ...        ...                            ...
# 187               2  Psalter         39  I waited patiently for the...
# 188               3  Psalter         54  Give ear to my prayer, O G...
# 189               4  Psalter        142  Hear my prayer, O Lord; gi...
# 190               5  Psalter         68  Save me, O God, for the wa...
# 191               6  Psalter         70  In Thee, O Lord, have I pu...
#
#      HumanScore  Similarity Score (%)
# 0          10.0                 43.73
# 1           0.0                 41.00
# 2           8.0                 40.99
# 3           4.0                 38.74
# 4           9.0                 38.43
# ..          ...                   ...
# 187         9.0                 21.90
# 188         6.0                 21.33
# 189         9.0                 20.87
# 190         4.0                 19.55
# 191        10.0                 19.11
#
# [192 rows x 9 columns]

# %%
scores = scores.rename(columns={"HumanScore": "Human Score"})

# %%
# filtering to only be studying the top 5 results from each query
scores = scores[scores['numbered_result'] != 6]


pd.set_option("display.max_rows", 50)

scores[scores['Method'] == 'TFIDF']
# Out:
#                              Query              Query Category Method  \
# 144                          mercy      Simple Keyword Queries  TFIDF
# 145                          mercy      Simple Keyword Queries  TFIDF
# 146                          mercy      Simple Keyword Queries  TFIDF
# 147                          mercy      Simple Keyword Queries  TFIDF
# 148                          mercy      Simple Keyword Queries  TFIDF
# 150        The Lord is my shepherd  Phrase/Exact Match Queries  TFIDF
# 151        The Lord is my shepherd  Phrase/Exact Match Queries  TFIDF
# 152        The Lord is my shepherd  Phrase/Exact Match Queries  TFIDF
# 153        The Lord is my shepherd  Phrase/Exact Match Queries  TFIDF
# 154        The Lord is my shepherd  Phrase/Exact Match Queries  TFIDF
# 156        protection from enemies   Thematic/Semantic Queries  TFIDF
# 157        protection from enemies   Thematic/Semantic Queries  TFIDF
# 158        protection from enemies   Thematic/Semantic Queries  TFIDF
# 159        protection from enemies   Thematic/Semantic Queries  TFIDF
# 160        protection from enemies   Thematic/Semantic Queries  TFIDF
# 162   praise in times of suffering   Thematic/Semantic Queries  TFIDF
# 163   praise in times of suffering   Thematic/Semantic Queries  TFIDF
# 164   praise in times of suffering   Thematic/Semantic Queries  TFIDF
# 165   praise in times of suffering   Thematic/Semantic Queries  TFIDF
# 166   praise in times of suffering   Thematic/Semantic Queries  TFIDF
# 168  How does the psalmist expr...        Long/Complex Queries  TFIDF
# 169  How does the psalmist expr...        Long/Complex Queries  TFIDF
# 170  How does the psalmist expr...        Long/Complex Queries  TFIDF
# 171  How does the psalmist expr...        Long/Complex Queries  TFIDF
# 172  How does the psalmist expr...        Long/Complex Queries  TFIDF
# 174  Verses where the psalmist ...        Long/Complex Queries  TFIDF
# 175  Verses where the psalmist ...        Long/Complex Queries  TFIDF
# 176  Verses where the psalmist ...        Long/Complex Queries  TFIDF
# 177  Verses where the psalmist ...        Long/Complex Queries  TFIDF
# 178  Verses where the psalmist ...        Long/Complex Queries  TFIDF
# 180  Rejoice, O ye heavens, sou...                         NaN  TFIDF
# 181  Rejoice, O ye heavens, sou...                         NaN  TFIDF
# 182  Rejoice, O ye heavens, sou...                         NaN  TFIDF
# 183  Rejoice, O ye heavens, sou...                         NaN  TFIDF
# 184  Rejoice, O ye heavens, sou...                         NaN  TFIDF
# 186  Have mercy on me, O God, h...     Orthodox Service Quotes  TFIDF
# 187  Have mercy on me, O God, h...     Orthodox Service Quotes  TFIDF
# 188  Have mercy on me, O God, h...     Orthodox Service Quotes  TFIDF
# 189  Have mercy on me, O God, h...     Orthodox Service Quotes  TFIDF
# 190  Have mercy on me, O God, h...     Orthodox Service Quotes  TFIDF
#
#     numbered_result     Text  Psalm Num                          Verse  \
# 144               1  Psalter        135  O give thanks unto the Lor...
# 145               2    Bible        135  1Alleluia Give thanks to t...
# 146               3    Bible         56  1For the End corrupt not b...
# 147               4  Psalter        122  Unto Thee have I lifted up...
# 148               5    Bible        102  By David Bless the Lord O ...
# 150               1  Psalter        145  Praise the Lord, O my soul...
# 151               2  Psalter        137  I will give Thee thanks, O...
# 152               3    Bible          2  Why do the nations rage An...
# 153               4    Bible         22  A psalm by David The Lord ...
# 154               5  Psalter         27  Unto Thee will I cry, O Lo...
# 156               1    Bible         70  By David of the sons of Jo...
# 157               2  Psalter        150  Praise God in His holy one...
# 158               3    Bible        103  By David Bless the Lord O ...
# 159               4    Bible         96  By David when His earth is...
# 160               5    Bible         97  A psalm by David Sing a ne...
# 162               1  Psalter         23  The earth is the Lord's, a...
# 163               2  Psalter        150  Praise God in His holy one...
# 164               3    Bible        150  1Alleluia Praise God in Hi...
# 165               4    Bible        148  Alleluia of Aggeus and Zac...
# 166               5    Bible        116  Alleluia Praise the Lord a...
# 168               1  Psalter         86  His foundations are in the...
# 169               2  Psalter         23  The earth is the Lord's, a...
# 170               3    Bible        117  Alleluia Give thanks to th...
# 171               4  Psalter         61  Shall not my soul be subje...
# 172               5    Bible         21  For the End concerning hel...
# 174               1  Psalter         86  His foundations are in the...
# 175               2  Psalter         23  The earth is the Lord's, a...
# 176               3    Bible        130  1An ode of ascents by Davi...
# 177               4  Psalter         61  Shall not my soul be subje...
# 178               5  Psalter         35  The transgressor, that he ...
# 180               1  Psalter        116  O praise the Lord, all ye ...
# 181               2  Psalter         23  The earth is the Lord's, a...
# 182               3  Psalter        148  Praise ye the Lord from th...
# 183               4  Psalter          4  Thou hast heard me when I ...
# 184               5  Psalter        133  Behold now, bless ye the L...
# 186               1  Psalter         85  Bow down Thine ear, O Lord...
# 187               2  Psalter         39  I waited patiently for the...
# 188               3  Psalter         54  Give ear to my prayer, O G...
# 189               4  Psalter        142  Hear my prayer, O Lord; gi...
# 190               5  Psalter         68  Save me, O God, for the wa...
#
#      Human Score  Similarity Score (%)
# 144          7.0                 33.96
# 145          7.0                 30.36
# 146          4.0                 21.89
# 147          2.0                 19.24
# 148          9.0                 16.78
# 150          4.0                 15.55
# 151          9.0                 11.46
# 152          9.0                 10.65
# 153         10.0                 10.59
# 154          8.0                 10.59
# 156          7.0                 10.10
# 157          7.0                  0.00
# 158          8.0                  0.00
# 159          8.0                  0.00
# 160          4.0                  0.00
# 162          2.0                 17.47
# 163          3.0                 16.35
# 164          3.0                 15.79
# 165         10.0                 11.60
# 166          5.0                 11.37
# 168          7.0                 16.65
# 169          3.0                 10.53
# 170          5.0                 10.38
# 171          8.0                  7.62
# 172          9.0                  7.58
# 174          2.0                 16.33
# 175          2.0                  9.98
# 176          1.0                  7.79
# 177          3.0                  7.08
# 178          8.0                  5.61
# 180         10.0                 25.45
# 181          7.0                 24.06
# 182          6.0                 22.41
# 183          2.0                 21.88
# 184          2.0                 19.35
# 186          9.0                 22.22
# 187          9.0                 21.90
# 188          6.0                 21.33
# 189          9.0                 20.87
# 190          4.0                 19.55

# %% [markdown]
# ## Quick Adjustment of the Data
# I have relaized that I completely forgot to add the results from **TF_IDF** to the blind scoring. TO fix this I am going to omit the query in total. Trying to blindly score the last 5 results, without bias will be difficult

# %%
scores = scores[scores['Query'] != "For the Peace of the world"]

scores
# Out:
#                              Query           Query Category       Method  \
# 16                           mercy   Simple Keyword Queries  TFIDF_GLoVe
# 17                           mercy   Simple Keyword Queries  TFIDF_GLoVe
# 18                           mercy   Simple Keyword Queries  TFIDF_GLoVe
# 19                           mercy   Simple Keyword Queries  TFIDF_GLoVe
# 20                           mercy   Simple Keyword Queries  TFIDF_GLoVe
# ..                             ...                      ...          ...
# 186  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 187  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 188  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 189  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
# 190  Have mercy on me, O God, h...  Orthodox Service Quotes        TFIDF
#
#     numbered_result     Text  Psalm Num                          Verse  \
# 16                1    Bible        135  1Alleluia Give thanks to t...
# 17                2  Psalter        135  O give thanks unto the Lor...
# 18                3    Bible        117  Alleluia Give thanks to th...
# 19                4    Bible        102  By David Bless the Lord O ...
# 20                5  Psalter        117  O give thanks unto the Lor...
# ..              ...      ...        ...                            ...
# 186               1  Psalter         85  Bow down Thine ear, O Lord...
# 187               2  Psalter         39  I waited patiently for the...
# 188               3  Psalter         54  Give ear to my prayer, O G...
# 189               4  Psalter        142  Hear my prayer, O Lord; gi...
# 190               5  Psalter         68  Save me, O God, for the wa...
#
#      Human Score  Similarity Score (%)
# 16           8.0                 82.61
# 17           9.0                 82.19
# 18           9.0                 69.03
# 19          10.0                 66.82
# 20          10.0                 66.30
# ..           ...                   ...
# 186          9.0                 22.22
# 187          9.0                 21.90
# 188          6.0                 21.33
# 189          9.0                 20.87
# 190          4.0                 19.55
#
# [160 rows x 9 columns]

# %% [markdown]
# ## Analysis
#
# With all of the inital proccessing and cleaning done, we are start to look at the data and work at drawing conclusions.
#
# ### Overall results

# %%
overall = pd.pivot_table(scores, index=["Method"], values="Human Score", aggfunc='mean')
overall
# Out:
#              Human Score
# Method
# BERT               6.700
# SBERT              5.075
# TFIDF              5.950
# TFIDF_GLoVe        5.975

# %%
pd.pivot_table(scores, index=["Method"], values="Human Score", aggfunc='count
               ')
# Out:
#              Human Score
# Method
# BERT                  40
# SBERT                 40
# TFIDF                 40
# TFIDF_GLoVe           40

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by Method and compute mean
method_avg = scores.groupby('Method')['Human Score'].mean().reset_index()

# Bar plot
plt.figure(figsize=(8,5))
sns.barplot(
    data=method_avg,
    x='Method',
    y='Human Score',
    palette='viridis'
)
plt.title("Average Human Score by Method")
plt.ylabel("Average Human Score")
plt.xlabel("Method")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Each Method per Query

# %%
pd.pivot_table(scores, index=["Method", "Query Category", "Query"], values="Human Score", aggfunc='mean')
# Out:
#                                                                        Human Score
# Method      Query Category             Query
# BERT        Long/Complex Queries       How does the psalmist expre...          6.4
#                                        Verses where the psalmist r...          7.0
#             Orthodox Service Quotes    Have mercy on me, O God, ha...          8.2
#             Phrase/Exact Match Queries The Lord is my shepherd                 6.2
#             Simple Keyword Queries     mercy                                   4.0
#             Thematic/Semantic Queries  praise in times of suffering            5.6
#                                        protection from enemies                 9.2
# SBERT       Long/Complex Queries       How does the psalmist expre...          6.0
#                                        Verses where the psalmist r...          6.8
#             Orthodox Service Quotes    Have mercy on me, O God, ha...          5.2
#             Phrase/Exact Match Queries The Lord is my shepherd                 4.0
#             Simple Keyword Queries     mercy                                   3.4
#             Thematic/Semantic Queries  praise in times of suffering            3.6
#                                        protection from enemies                 5.2
# TFIDF       Long/Complex Queries       How does the psalmist expre...          6.4
#                                        Verses where the psalmist r...          3.2
#             Orthodox Service Quotes    Have mercy on me, O God, ha...          7.4
#             Phrase/Exact Match Queries The Lord is my shepherd                 8.0
#             Simple Keyword Queries     mercy                                   5.8
#             Thematic/Semantic Queries  praise in times of suffering            4.6
#                                        protection from enemies                 6.8
# TFIDF_GLoVe Long/Complex Queries       How does the psalmist expre...          6.2
#                                        Verses where the psalmist r...          5.0
#             Orthodox Service Quotes    Have mercy on me, O God, ha...          6.2
#             Phrase/Exact Match Queries The Lord is my shepherd                 3.6
#             Simple Keyword Queries     mercy                                   9.2
#             Thematic/Semantic Queries  praise in times of suffering            5.0
#                                        protection from enemies                 5.2

# %%
pd.pivot_table(scores, index=["Method", "Query Category"], values="Human Score", aggfunc='mean')
# Out:
#                                         Human Score
# Method      Query Category
# BERT        Long/Complex Queries                6.7
#             Orthodox Service Quotes             8.2
#             Phrase/Exact Match Queries          6.2
#             Simple Keyword Queries              4.0
#             Thematic/Semantic Queries           7.4
# SBERT       Long/Complex Queries                6.4
#             Orthodox Service Quotes             5.2
#             Phrase/Exact Match Queries          4.0
#             Simple Keyword Queries              3.4
#             Thematic/Semantic Queries           4.4
# TFIDF       Long/Complex Queries                4.8
#             Orthodox Service Quotes             7.4
#             Phrase/Exact Match Queries          8.0
#             Simple Keyword Queries              5.8
#             Thematic/Semantic Queries           5.7
# TFIDF_GLoVe Long/Complex Queries                5.6
#             Orthodox Service Quotes             6.2
#             Phrase/Exact Match Queries          3.6
#             Simple Keyword Queries              9.2
#             Thematic/Semantic Queries           5.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Pivot table
pivot = pd.pivot_table(
    scores,
    index=["Method", "Query Category"],
    values="Human Score",
    aggfunc='mean'
).reset_index()

# Unique methods
methods = pivot['Method'].unique()
n_methods = len(methods)

# Determine layout: 2 rows
n_rows = 2
n_cols = math.ceil(n_methods / n_rows)

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 5*n_rows), sharey=True)
axes = axes.flatten()  # flatten in case of 2D array

# Plot each method
for ax, method in zip(axes, methods):
    subset = pivot[pivot['Method'] == method]
    sns.barplot(
        data=subset,
        x='Query Category',
        y='Human Score',a
        palette='viridis'
    )
    
    
    ax.set_title(method)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    ax.set_xlabel("Query Category")
    ax.set_ylabel("Human Score")

# Turn off any unused axes
for ax in axes[n_methods:]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
pd.pivot_table(
    scores,
    index=["Method", "Query Category", "Query"],
    values="Human Score",
    aggfunc='mean'
).reset_index()
# Out:
#          Method              Query Category                          Query  \
# 0          BERT        Long/Complex Queries  How does the psalmist expr...
# 1          BERT        Long/Complex Queries  Verses where the psalmist ...
# 2          BERT     Orthodox Service Quotes  Have mercy on me, O God, h...
# 3          BERT  Phrase/Exact Match Queries        The Lord is my shepherd
# 4          BERT      Simple Keyword Queries                          mercy
# 5          BERT   Thematic/Semantic Queries   praise in times of suffering
# 6          BERT   Thematic/Semantic Queries        protection from enemies
# 7         SBERT        Long/Complex Queries  How does the psalmist expr...
# 8         SBERT        Long/Complex Queries  Verses where the psalmist ...
# 9         SBERT     Orthodox Service Quotes  Have mercy on me, O God, h...
# 10        SBERT  Phrase/Exact Match Queries        The Lord is my shepherd
# 11        SBERT      Simple Keyword Queries                          mercy
# 12        SBERT   Thematic/Semantic Queries   praise in times of suffering
# 13        SBERT   Thematic/Semantic Queries        protection from enemies
# 14        TFIDF        Long/Complex Queries  How does the psalmist expr...
# 15        TFIDF        Long/Complex Queries  Verses where the psalmist ...
# 16        TFIDF     Orthodox Service Quotes  Have mercy on me, O God, h...
# 17        TFIDF  Phrase/Exact Match Queries        The Lord is my shepherd
# 18        TFIDF      Simple Keyword Queries                          mercy
# 19        TFIDF   Thematic/Semantic Queries   praise in times of suffering
# 20        TFIDF   Thematic/Semantic Queries        protection from enemies
# 21  TFIDF_GLoVe        Long/Complex Queries  How does the psalmist expr...
# 22  TFIDF_GLoVe        Long/Complex Queries  Verses where the psalmist ...
# 23  TFIDF_GLoVe     Orthodox Service Quotes  Have mercy on me, O God, h...
# 24  TFIDF_GLoVe  Phrase/Exact Match Queries        The Lord is my shepherd
# 25  TFIDF_GLoVe      Simple Keyword Queries                          mercy
# 26  TFIDF_GLoVe   Thematic/Semantic Queries   praise in times of suffering
# 27  TFIDF_GLoVe   Thematic/Semantic Queries        protection from enemies
#
#     Human Score
# 0           6.4
# 1           7.0
# 2           8.2
# 3           6.2
# 4           4.0
# 5           5.6
# 6           9.2
# 7           6.0
# 8           6.8
# 9           5.2
# 10          4.0
# 11          3.4
# 12          3.6
# 13          5.2
# 14          6.4
# 15          3.2
# 16          7.4
# 17          8.0
# 18          5.8
# 19          4.6
# 20          6.8
# 21          6.2
# 22          5.0
# 23          6.2
# 24          3.6
# 25          9.2
# 26          5.0
# 27          5.2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Pivot table
pivot = pd.pivot_table(
    scores,
    index=["Method", "Query Category"],
    values="Human Score",
    aggfunc='mean'
).reset_index()

# Unique methods
methods = pivot['Method'].unique()
n_methods = len(methods)

# Determine layout: 2 rows
n_rows = 2
n_cols = math.ceil(n_methods / n_rows)

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 5*n_rows), sharey=True)
axes = axes.flatten()  # flatten in case of 2D array

# Plot each method
for ax, method in zip(axes, methods):
    subset = pivot[pivot['Method'] == method]
    
    # Bar plot
    sns.barplot(
        data=subset,
        x='Query Category',
        y='Human Score',
        ax=ax,
        palette='viridis'
    )
    
    # Compute overall average for this method
    method_avg = subset['Human Score'].mean()
    
    # Add horizontal line
    ax.axhline(method_avg, color='red', linestyle='--', label=f"Avg: {method_avg:.2f}")
    
    # Title and labels
    ax.set_title(method)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    ax.set_xlabel("Query Category")
    ax.set_ylabel("Human Score")
    
    # Optional: add legend for the line
    ax.legend()


# Turn off any unused axes
for ax in axes[n_methods:]:
    ax.axis('off')
    
fig.suptitle("***ERROR** Query Category Scores based on Overall per Method")
plt.tight_layout()
plt.show()

# %%
import math
import matplotlib.pyplot as plt
import seaborn as sns

# Pivot table for plotting by method & query category
pivot = pd.pivot_table(
    scores,
    index=["Method", "Query Category"],
    values="Human Score",
    aggfunc='mean'
).reset_index()

methods = pivot['Method'].unique()
n_methods = len(methods)

# Layout: 2 rows
n_rows = 2
n_cols = math.ceil(n_methods / n_rows)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 5*n_rows), sharey=True)
axes = axes.flatten()

for ax, method in zip(axes, methods):
    subset = pivot[pivot['Method'] == method]

    sns.barplot(
        data=subset,
        x='Query Category',
        y='Human Score',
        ax=ax,
        palette='viridis'
    )

    # Use your pivot table to get the method average
    method_avg = overall.loc[method, "Human Score"]
    
    ax.axhline(method_avg, color='red', linestyle='--', label=f"Avg: {method_avg:.4}")

    ax.set_title(method)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    ax.set_xlabel("Query Category")
    ax.set_ylabel("Human Score")
    ax.legend()

# Turn off unused axes
for ax in axes[n_methods:]:
    ax.axis('off')

fig.suptitle("Query Category Scores based on Overall per Method")

plt.tight_layout()
plt.show()

# %%
overall
# Out:
#              Human Score
# Method
# BERT               6.700
# SBERT              5.075
# TFIDF              5.950
# TFIDF_GLoVe        5.975

# %%
def wrap_labels(ax, width=15):
    labels = [
        textwrap.fill(label.get_text(), width=width)
        for label in ax.get_xticklabels()
    ]
    ax.set_xticklabels(labels, rotation=0, ha="center")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# -----------------------------
# Pivot table: Method × Query
# -----------------------------
pivot = pd.pivot_table(
    scores,
    index=["Method", "Query"],
    values="Human Score",
    aggfunc="mean"
).reset_index()

# -----------------------------
# Create Query IDs (Q1, Q2, ...)
# -----------------------------
query_map = (
    pivot[["Query"]]
    .drop_duplicates()
    .reset_index(drop=True)
)
query_map["Query ID"] = [f"Q{i + 1}" for i in range(len(query_map))]

query_lookup = dict(zip(query_map["Query"], query_map["Query ID"]))
pivot["Query ID"] = pivot["Query"].map(query_lookup)

# -----------------------------
# Layout configuration
# -----------------------------
methods = pivot["Method"].unique()
n_methods = len(methods)

n_rows = 2
n_cols = math.ceil(n_methods / n_rows)

fig, axes = plt.subplots(
    n_rows,
    n_cols,
    figsize=(6 * n_cols, 5 * n_rows),
    sharey=True
)

axes = axes.flatten()

# -----------------------------
# Plot each method
# -----------------------------
for ax, method in zip(axes, methods):
    subset = pivot[pivot["Method"] == method]

    sns.barplot(
        data=subset,
        x="Query ID",
        y="Human Score",
        ax=ax,
        palette="viridis"
    )

    ax.set_title(method)
    ax.set_xlabel("Query")
    ax.set_ylabel("Human Score")

# Turn off unused axes
for ax in axes[n_methods:]:
    ax.axis("off")

# -----------------------------
# Add query descriptions at bottom
# -----------------------------
query_text = "\n".join(
    f"{row['Query ID']} – {row['Query']}"
    for _, row in query_map.iterrows()
)

# Adjust y-coordinate for positioning the text
fig.text(
    0.5,
    0.04,  # Adjusted to provide more space below the plots
    query_text,
    ha="center",
    va="top",
    fontsize=12,
    wrap=True,
    linespacing=1.5
)

# -----------------------------
# Final layout
# -----------------------------
fig.suptitle(
    "Human Evaluation Scores by Query for Each Method",
    fontsize=16
)

plt.tight_layout(rect=[0, 0.1, 1, 1])  # Adjusted to keep space for the title and bottom text
plt.show()

# %% [markdown]
# # Looking at indivual Numbered results

# %%
numbered = pd.pivot_table(scores, index=['Method', 'numbered_result'], values='Human Score', aggfunc='mean').reset_index()
numbered
# Out:
#          Method  numbered_result  Human Score
# 0          BERT                1        5.000
# 1          BERT                2        7.875
# 2          BERT                3        5.875
# 3          BERT                4        8.000
# 4          BERT                5        6.750
# 5         SBERT                1        3.625
# 6         SBERT                2        4.750
# 7         SBERT                3        6.250
# 8         SBERT                4        5.625
# 9         SBERT                5        5.125
# 10        TFIDF                1        6.000
# 11        TFIDF                2        5.875
# 12        TFIDF                3        5.250
# 13        TFIDF                4        6.500
# 14        TFIDF                5        6.125
# 15  TFIDF_GLoVe                1        6.875
# 16  TFIDF_GLoVe                2        6.500
# 17  TFIDF_GLoVe                3        4.875
# 18  TFIDF_GLoVe                4        6.250
# 19  TFIDF_GLoVe                5        5.375

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

sns.barplot(
    data=numbered,
    x='numbered_result',
    y='Human Score'
)

plt.xlabel("Result Number")
plt.ylabel("Human Score")

# Main title
plt.title("1 being the best; 5 being the 5th best", fontsize=12)

# Subtitle (smaller font, right below the main title)
plt.suptitle("Mean Human Score by Result Number", fontsize=18, y=1)  # if using figu

plt.show()

# %% [markdown]
# From this graph, it looks as though the *4th* best results seems to have the best over blind score out of all of the data. This is very surprising. Lets breack the graph down further to each how each method does as well.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.barplot(
    data=numbered,
    x='numbered_result',
    y='Human Score',
    hue='Method',   # optional
    palette='viridis',
    errorbar=None   # <-- removes the black lines
)


plt.xlabel("Result Number")
plt.ylabel("Human Score")

# Main title
plt.title("1 being the best & 5 being the 5th best", fontsize=12)

# Subtitle (smaller font, right below the main title)
plt.suptitle("Mean Human Score by Result Number", fontsize=18, y=0.95) # if using figure

plt.legend(title="Method", loc='upper right')


plt.show()

# %% [markdown]
# ## Observations
# ### `BERT`
# - Overall, `BERT` preforms the best at almost every number except at the **1st** and **3rd**
#     - Has the most variation in scores from 5~8
# ### `SBERT`
#
# - seems to prefrom the best when ever the results is the **3rd** best result in any algorithm
# - platues
#
#
# ### `TFIDF`
#
# ### `TFIDF_GLOVE`
# - Seems to only improve the effectiveness of the restuls overall for the top 2 resuilts of a query
#
#
#
#
# ### Top Results
# - the "best" result for queries has the most variation in the score, than all other results based on the placement
