# %% [markdown]
# # Working through the Blind Scoring
#
# After taking the 8 quieres and running then through the four different queries from a previous notebook, I was able to blind score each result that was attached to one of the queries. I scored them on a scale of 0 - 10, with:
# - **0** – No semantic relationship
# - **1–3** – Minimal semantic overlap
# - **4–6** – Partial or contextual relevance
# - **7–9** – Strong semantic alignment
# - **10** – Exact or near-exact semantic match
#
# This notebook will now closely lopok my my blind scoring in a couple of different ways.

# %%
import pandas as pd

scores = pd.read_csv("results_scored.csv")

scores = scores.iloc[:, :-2]

# %%
scores
# Out:
#                                                  Query       Method  \
# 0                           For the Peace of the world  TFIDF_GLoVe
# 1                           For the Peace of the world  TFIDF_GLoVe
# 2                           For the Peace of the world  TFIDF_GLoVe
# 3                           For the Peace of the world  TFIDF_GLoVe
# 4                           For the Peace of the world  TFIDF_GLoVe
# ..                                                 ...          ...
# 187  Have mercy on me, O God, have mercy on me. For...        TFIDF
# 188  Have mercy on me, O God, have mercy on me. For...        TFIDF
# 189  Have mercy on me, O God, have mercy on me. For...        TFIDF
# 190  Have mercy on me, O God, have mercy on me. For...        TFIDF
# 191  Have mercy on me, O God, have mercy on me. For...        TFIDF
#
#      Similarity Score (%)     Text  Psalm Num  \
# 0                   43.73    Bible         92
# 1                   41.00  Psalter        121
# 2                   40.99    Bible        121
# 3                   38.74    Bible        131
# 4                   38.43    Bible         96
# ..                    ...      ...        ...
# 187                 21.90  Psalter         39
# 188                 21.33  Psalter         54
# 189                 20.87  Psalter        142
# 190                 19.55  Psalter         68
# 191                 19.11  Psalter         70
#
#                                                  Verse  HumanScore
# 0    1For the day before the Sabbath when the earth...        10.0
# 1    I was glad because of them that said to me, Le...         0.0
# 2    1An ode of ascents Iwas glad when they said to...         8.0
# 3    1An ode of ascents Remember David O Lord And a...         4.0
# 4    By David when His earth is restored The Lord r...         9.0
# ..                                                 ...         ...
# 187  I waited patiently for the Lord, and He inclin...         9.0
# 188  Give ear to my prayer, O God, and despise not ...         6.0
# 189  Hear my prayer, O Lord; give ear unto my suppl...         9.0
# 190  Save me, O God, for the waters are come in unt...         4.0
# 191  In Thee, O Lord, have I put my hope; let me ne...        10.0
#
# [192 rows x 7 columns]

# %% [markdown]
# Among the 8 queires, there are 4 different categories of queires and they are as followed.
#
# ## Querie Categories
# #### 1. Simple Keyword Queries
# - **Query 1:** mercy
#
# #### 2. Phrase/Exact Match Queries
# - **Query 2:** The Lord is my shepherd
#
# #### 3. Thematic/Semantic Queries
# - **Query 3:** protection from enemies
# - **Query 4:** praise in times of suffering
#
# #### 4. Long/Complex Queries
# - **Query 5:** How does the psalmist express trust in God while surrounded by fear and uncertainty?
# - **Query 6:** Verses where the psalmist remembers past deliverance and uses it to find hope in present trials.
#
# #### 5. Orthodox Service Quotes
# ##### From *Vespers*
# - **Query 7:**
#     >"Rejoice, O ye heavens, sound the trumpets, ye foundation of the earth, thunder forth gladness, O ye mountains: for behold, Emanuel to    the Cross our sins, and the Giver of Life hath slain death, rasing up Adam,; for He loveth man kind."
#
# - **Query 8:**
#     >"“Have mercy on me, O God, have mercy on me. For my soul trusts in Thee, and in the shadow of Thy wings will I hope, until iniquity pass away.”
#
# ##### From *"The Great Litany"*
# - **Query 9**
#     >"For the Peace of the world."
#
# We are going to be adding these query categories to the data itself before begining analysis. Building in this categorical variable, there is a further breakdown that can be done inorder to find results and conclusions.

# %%
QUERY_TO_CATEGORY = {
    "mercy": "Simple Keyword Queries",
    "The Lord is my shepherd": "Phrase/Exact Match Queries",
    "protection from enemies": "Thematic/Semantic Queries",
    "praise in times of suffering": "Thematic/Semantic Queries",
    "How does the psalmist express trust in God while surrounded by fear and uncertainty?":
        "Long/Complex Queries",
    "Verses where the psalmist remembers past deliverance and uses it to find hope in present trials.":
        "Long/Complex Queries",
    "Rejoice, O ye heavens, sound the trumpets, ye foundation of the earth, thunder forth gladness, O ye mountains: for behold, Emanuel to the Cross our sins, and the Giver of Life hath slain death, raising up Adam; for He loveth mankind.":
        "Orthodox Service Quotes",
    "Have mercy on me, O God, have mercy on me. For my soul trusts in Thee, and in the shadow of Thy wings will I hope, until iniquity pass away.":
        "Orthodox Service Quotes",
    "For the Peace of the world": "Orthodox Service Quotes"
}

# %%
scores["Query Category"] = scores["Query"].map(QUERY_TO_CATEGORY)
scores
# Out:
#                                                  Query       Method  \
# 0                           For the Peace of the world  TFIDF_GLoVe
# 1                           For the Peace of the world  TFIDF_GLoVe
# 2                           For the Peace of the world  TFIDF_GLoVe
# 3                           For the Peace of the world  TFIDF_GLoVe
# 4                           For the Peace of the world  TFIDF_GLoVe
# ..                                                 ...          ...
# 187  Have mercy on me, O God, have mercy on me. For...        TFIDF
# 188  Have mercy on me, O God, have mercy on me. For...        TFIDF
# 189  Have mercy on me, O God, have mercy on me. For...        TFIDF
# 190  Have mercy on me, O God, have mercy on me. For...        TFIDF
# 191  Have mercy on me, O God, have mercy on me. For...        TFIDF
#
#      Similarity Score (%)     Text  Psalm Num  \
# 0                   43.73    Bible         92
# 1                   41.00  Psalter        121
# 2                   40.99    Bible        121
# 3                   38.74    Bible        131
# 4                   38.43    Bible         96
# ..                    ...      ...        ...
# 187                 21.90  Psalter         39
# 188                 21.33  Psalter         54
# 189                 20.87  Psalter        142
# 190                 19.55  Psalter         68
# 191                 19.11  Psalter         70
#
#                                                  Verse  HumanScore  \
# 0    1For the day before the Sabbath when the earth...        10.0
# 1    I was glad because of them that said to me, Le...         0.0
# 2    1An ode of ascents Iwas glad when they said to...         8.0
# 3    1An ode of ascents Remember David O Lord And a...         4.0
# 4    By David when His earth is restored The Lord r...         9.0
# ..                                                 ...         ...
# 187  I waited patiently for the Lord, and He inclin...         9.0
# 188  Give ear to my prayer, O God, and despise not ...         6.0
# 189  Hear my prayer, O Lord; give ear unto my suppl...         9.0
# 190  Save me, O God, for the waters are come in unt...         4.0
# 191  In Thee, O Lord, have I put my hope; let me ne...        10.0
#
#               Query Category
# 0    Orthodox Service Quotes
# 1    Orthodox Service Quotes
# 2    Orthodox Service Quotes
# 3    Orthodox Service Quotes
# 4    Orthodox Service Quotes
# ..                       ...
# 187  Orthodox Service Quotes
# 188  Orthodox Service Quotes
# 189  Orthodox Service Quotes
# 190  Orthodox Service Quotes
# 191  Orthodox Service Quotes
#
# [192 rows x 8 columns]

# %%
# reordering the columns of the dataframe
scores = scores [["Query", "Query Category", "Method", "Text", "Psalm Num", 
                  "Verse", "HumanScore", "Similarity Score (%)"]]

scores
# Out:
#                                                  Query  \
# 0                           For the Peace of the world
# 1                           For the Peace of the world
# 2                           For the Peace of the world
# 3                           For the Peace of the world
# 4                           For the Peace of the world
# ..                                                 ...
# 187  Have mercy on me, O God, have mercy on me. For...
# 188  Have mercy on me, O God, have mercy on me. For...
# 189  Have mercy on me, O God, have mercy on me. For...
# 190  Have mercy on me, O God, have mercy on me. For...
# 191  Have mercy on me, O God, have mercy on me. For...
#
#               Query Category       Method     Text  Psalm Num  \
# 0    Orthodox Service Quotes  TFIDF_GLoVe    Bible         92
# 1    Orthodox Service Quotes  TFIDF_GLoVe  Psalter        121
# 2    Orthodox Service Quotes  TFIDF_GLoVe    Bible        121
# 3    Orthodox Service Quotes  TFIDF_GLoVe    Bible        131
# 4    Orthodox Service Quotes  TFIDF_GLoVe    Bible         96
# ..                       ...          ...      ...        ...
# 187  Orthodox Service Quotes        TFIDF  Psalter         39
# 188  Orthodox Service Quotes        TFIDF  Psalter         54
# 189  Orthodox Service Quotes        TFIDF  Psalter        142
# 190  Orthodox Service Quotes        TFIDF  Psalter         68
# 191  Orthodox Service Quotes        TFIDF  Psalter         70
#
#                                                  Verse  HumanScore  \
# 0    1For the day before the Sabbath when the earth...        10.0
# 1    I was glad because of them that said to me, Le...         0.0
# 2    1An ode of ascents Iwas glad when they said to...         8.0
# 3    1An ode of ascents Remember David O Lord And a...         4.0
# 4    By David when His earth is restored The Lord r...         9.0
# ..                                                 ...         ...
# 187  I waited patiently for the Lord, and He inclin...         9.0
# 188  Give ear to my prayer, O God, and despise not ...         6.0
# 189  Hear my prayer, O Lord; give ear unto my suppl...         9.0
# 190  Save me, O God, for the waters are come in unt...         4.0
# 191  In Thee, O Lord, have I put my hope; let me ne...        10.0
#
#      Similarity Score (%)
# 0                   43.73
# 1                   41.00
# 2                   40.99
# 3                   38.74
# 4                   38.43
# ..                    ...
# 187                 21.90
# 188                 21.33
# 189                 20.87
# 190                 19.55
# 191                 19.11
#
# [192 rows x 8 columns]

# %% [markdown]
# ## Numbering the Results
# I also want to be able to reference the order of the results within each search. I collected the top 5 results from each search. There was a bug in my code that took the top 6 results from searches. I am going to just worry about the top 5 results to keep everything fair.

# %%
# temporary dataframe to not break the original 
temp = scores.copy()

# aqdding a column to number the indivudal results
temp['numbered_result'] = pd.NA
temp
# Out:
#                                                  Query  \
# 0                           For the Peace of the world
# 1                           For the Peace of the world
# 2                           For the Peace of the world
# 3                           For the Peace of the world
# 4                           For the Peace of the world
# ..                                                 ...
# 187  Have mercy on me, O God, have mercy on me. For...
# 188  Have mercy on me, O God, have mercy on me. For...
# 189  Have mercy on me, O God, have mercy on me. For...
# 190  Have mercy on me, O God, have mercy on me. For...
# 191  Have mercy on me, O God, have mercy on me. For...
#
#               Query Category       Method     Text  Psalm Num  \
# 0    Orthodox Service Quotes  TFIDF_GLoVe    Bible         92
# 1    Orthodox Service Quotes  TFIDF_GLoVe  Psalter        121
# 2    Orthodox Service Quotes  TFIDF_GLoVe    Bible        121
# 3    Orthodox Service Quotes  TFIDF_GLoVe    Bible        131
# 4    Orthodox Service Quotes  TFIDF_GLoVe    Bible         96
# ..                       ...          ...      ...        ...
# 187  Orthodox Service Quotes        TFIDF  Psalter         39
# 188  Orthodox Service Quotes        TFIDF  Psalter         54
# 189  Orthodox Service Quotes        TFIDF  Psalter        142
# 190  Orthodox Service Quotes        TFIDF  Psalter         68
# 191  Orthodox Service Quotes        TFIDF  Psalter         70
#
#                                                  Verse  HumanScore  \
# 0    1For the day before the Sabbath when the earth...        10.0
# 1    I was glad because of them that said to me, Le...         0.0
# 2    1An ode of ascents Iwas glad when they said to...         8.0
# 3    1An ode of ascents Remember David O Lord And a...         4.0
# 4    By David when His earth is restored The Lord r...         9.0
# ..                                                 ...         ...
# 187  I waited patiently for the Lord, and He inclin...         9.0
# 188  Give ear to my prayer, O God, and despise not ...         6.0
# 189  Hear my prayer, O Lord; give ear unto my suppl...         9.0
# 190  Save me, O God, for the waters are come in unt...         4.0
# 191  In Thee, O Lord, have I put my hope; let me ne...        10.0
#
#      Similarity Score (%) numbered_result
# 0                   43.73             NaN
# 1                   41.00             NaN
# 2                   40.99             NaN
# 3                   38.74             NaN
# 4                   38.43             NaN
# ..                    ...             ...
# 187                 21.90             NaN
# 188                 21.33             NaN
# 189                 20.87             NaN
# 190                 19.55             NaN
# 191                 19.11             NaN
#
# [192 rows x 9 columns]

# %%
n = temp.shape[0]

# starting with the number 1 result of a query
num_result = 1

query = temp["Query"].iloc[0]
method = temp["Method"].iloc[0]

for i in range(n):
    # checking if we are in the same group fo data to be numbered
    if query == temp["Query"].iloc[i] and method == temp["Method"].iloc[i]:
        temp["numbered_result"].iloc[i] = num_result
        num_result += 1
        
    # in an new group of results
    else:
        # the current result is the number result for the new set of results
        temp["numbered_result"].iloc[i] = 1
        # reset the number result
        num_result = 2
        # update to the new target query & method
        query = temp["Query"].iloc[i]
        method = temp["Method"].iloc[i]
# Out:
# /tmp/ipykernel_101/3907079077.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["numbered_result"].iloc[i] = num_result
# /tmp/ipykernel_101/3907079077.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["numbered_result"].iloc[i] = 1

# %%
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_colwidth", 30)

#temp.head(100)

# %%
pd.set_option("display.max_rows", 20)

# %%
# updating the original dataframe with the numbered results
scores = temp
scores
# Out:
#                                                  Query  \
# 0                           For the Peace of the world
# 1                           For the Peace of the world
# 2                           For the Peace of the world
# 3                           For the Peace of the world
# 4                           For the Peace of the world
# ..                                                 ...
# 187  Have mercy on me, O God, have mercy on me. For...
# 188  Have mercy on me, O God, have mercy on me. For...
# 189  Have mercy on me, O God, have mercy on me. For...
# 190  Have mercy on me, O God, have mercy on me. For...
# 191  Have mercy on me, O God, have mercy on me. For...
#
#               Query Category       Method     Text  Psalm Num  \
# 0    Orthodox Service Quotes  TFIDF_GLoVe    Bible         92
# 1    Orthodox Service Quotes  TFIDF_GLoVe  Psalter        121
# 2    Orthodox Service Quotes  TFIDF_GLoVe    Bible        121
# 3    Orthodox Service Quotes  TFIDF_GLoVe    Bible        131
# 4    Orthodox Service Quotes  TFIDF_GLoVe    Bible         96
# ..                       ...          ...      ...        ...
# 187  Orthodox Service Quotes        TFIDF  Psalter         39
# 188  Orthodox Service Quotes        TFIDF  Psalter         54
# 189  Orthodox Service Quotes        TFIDF  Psalter        142
# 190  Orthodox Service Quotes        TFIDF  Psalter         68
# 191  Orthodox Service Quotes        TFIDF  Psalter         70
#
#                                                  Verse  HumanScore  \
# 0    1For the day before the Sabbath when the earth...        10.0
# 1    I was glad because of them that said to me, Le...         0.0
# 2    1An ode of ascents Iwas glad when they said to...         8.0
# 3    1An ode of ascents Remember David O Lord And a...         4.0
# 4    By David when His earth is restored The Lord r...         9.0
# ..                                                 ...         ...
# 187  I waited patiently for the Lord, and He inclin...         9.0
# 188  Give ear to my prayer, O God, and despise not ...         6.0
# 189  Hear my prayer, O Lord; give ear unto my suppl...         9.0
# 190  Save me, O God, for the waters are come in unt...         4.0
# 191  In Thee, O Lord, have I put my hope; let me ne...        10.0
#
#      Similarity Score (%) numbered_result
# 0                   43.73               1
# 1                   41.00               2
# 2                   40.99               3
# 3                   38.74               4
# 4                   38.43               5
# ..                    ...             ...
# 187                 21.90               2
# 188                 21.33               3
# 189                 20.87               4
# 190                 19.55               5
# 191                 19.11               6
#
# [192 rows x 9 columns]

# %%
# reordering the columns
scores = scores [["Query", "Query Category", "Method", "numbered_result", "Text", "Psalm Num", 
                  "Verse", "HumanScore", "Similarity Score (%)"]]
scores
# Out:
#                                                  Query  \
# 0                           For the Peace of the world
# 1                           For the Peace of the world
# 2                           For the Peace of the world
# 3                           For the Peace of the world
# 4                           For the Peace of the world
# ..                                                 ...
# 187  Have mercy on me, O God, have mercy on me. For...
# 188  Have mercy on me, O God, have mercy on me. For...
# 189  Have mercy on me, O God, have mercy on me. For...
# 190  Have mercy on me, O God, have mercy on me. For...
# 191  Have mercy on me, O God, have mercy on me. For...
#
#               Query Category       Method numbered_result     Text  Psalm Num  \
# 0    Orthodox Service Quotes  TFIDF_GLoVe               1    Bible         92
# 1    Orthodox Service Quotes  TFIDF_GLoVe               2  Psalter        121
# 2    Orthodox Service Quotes  TFIDF_GLoVe               3    Bible        121
# 3    Orthodox Service Quotes  TFIDF_GLoVe               4    Bible        131
# 4    Orthodox Service Quotes  TFIDF_GLoVe               5    Bible         96
# ..                       ...          ...             ...      ...        ...
# 187  Orthodox Service Quotes        TFIDF               2  Psalter         39
# 188  Orthodox Service Quotes        TFIDF               3  Psalter         54
# 189  Orthodox Service Quotes        TFIDF               4  Psalter        142
# 190  Orthodox Service Quotes        TFIDF               5  Psalter         68
# 191  Orthodox Service Quotes        TFIDF               6  Psalter         70
#
#                                                  Verse  HumanScore  \
# 0    1For the day before the Sabbath when the earth...        10.0
# 1    I was glad because of them that said to me, Le...         0.0
# 2    1An ode of ascents Iwas glad when they said to...         8.0
# 3    1An ode of ascents Remember David O Lord And a...         4.0
# 4    By David when His earth is restored The Lord r...         9.0
# ..                                                 ...         ...
# 187  I waited patiently for the Lord, and He inclin...         9.0
# 188  Give ear to my prayer, O God, and despise not ...         6.0
# 189  Hear my prayer, O Lord; give ear unto my suppl...         9.0
# 190  Save me, O God, for the waters are come in unt...         4.0
# 191  In Thee, O Lord, have I put my hope; let me ne...        10.0
#
#      Similarity Score (%)
# 0                   43.73
# 1                   41.00
# 2                   40.99
# 3                   38.74
# 4                   38.43
# ..                    ...
# 187                 21.90
# 188                 21.33
# 189                 20.87
# 190                 19.55
# 191                 19.11
#
# [192 rows x 9 columns]

# %%
scores = scores.rename(columns={"HumanScore": "Human Score"})

# %% [markdown]
# ## Analysis
#
# With all of the inital proccessing and cleaning done, we are start to look at the data and work at drawing conclusions.
#
# ### Overall results

# %%
overall = pd.pivot_table(scores, index=["Method"], values="Human Score", aggfunc='mean')
overall
# Out:
#              Human Score
# Method
# BERT            6.533333
# SBERT           4.955556
# TFIDF           6.000000
# TFIDF_GLoVe     5.981481

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by Method and compute mean
method_avg = scores.groupby('Method')['Human Score'].mean().reset_index()

# Bar plot
plt.figure(figsize=(8,5))
sns.barplot(
    data=method_avg,
    x='Method',
    y='Human Score',
    palette='viridis'
)
plt.title("Average Human Score by Method")
plt.ylabel("Average Human Score")
plt.xlabel("Method")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Each Method per Query

# %%
pd.pivot_table(scores, index=["Method", "Query"], values="Human Score", aggfunc='mean')
# Out:
#                                             Human Score
# Method      Query
# BERT        For the Peace of the world         5.200000
#             Have mercy on me, O God, ha...     8.200000
#             How does the psalmist expre...     6.400000
#             Rejoice, O ye heavens, soun...     7.000000
#             The Lord is my shepherd            6.200000
#             Verses where the psalmist r...     7.000000
#             mercy                              4.000000
#             praise in times of suffering       5.600000
#             protection from enemies            9.200000
# SBERT       For the Peace of the world         4.000000
#             Have mercy on me, O God, ha...     5.200000
#             How does the psalmist expre...     6.000000
#             Rejoice, O ye heavens, soun...     6.400000
#             The Lord is my shepherd            4.000000
#             Verses where the psalmist r...     6.800000
#             mercy                              3.400000
#             praise in times of suffering       3.600000
#             protection from enemies            5.200000
# TFIDF       Have mercy on me, O God, ha...     7.833333
#             How does the psalmist expre...     6.666667
#             Rejoice, O ye heavens, soun...     5.666667
#             The Lord is my shepherd            6.833333
#             Verses where the psalmist r...     3.500000
#             mercy                              6.166667
#             praise in times of suffering       4.500000
#             protection from enemies            6.833333
# TFIDF_GLoVe For the Peace of the world         5.500000
#             Have mercy on me, O God, ha...     6.500000
#             How does the psalmist expre...     6.833333
#             Rejoice, O ye heavens, soun...     7.833333
#             The Lord is my shepherd            3.166667
#             Verses where the psalmist r...     4.833333
#             mercy                              9.000000
#             praise in times of suffering       5.333333
#             protection from enemies            4.833333

# %%
pd.pivot_table(scores, index=["Method", "Query Category"], values="Human Score", aggfunc='mean')
# Out:
#                                         Human Score
# Method      Query Category
# BERT        Long/Complex Queries           6.700000
#             Orthodox Service Quotes        6.700000
#             Phrase/Exact Match Queries     6.200000
#             Simple Keyword Queries         4.000000
#             Thematic/Semantic Queries      7.400000
# SBERT       Long/Complex Queries           6.400000
#             Orthodox Service Quotes        4.600000
#             Phrase/Exact Match Queries     4.000000
#             Simple Keyword Queries         3.400000
#             Thematic/Semantic Queries      4.400000
# TFIDF       Long/Complex Queries           5.083333
#             Orthodox Service Quotes        7.833333
#             Phrase/Exact Match Queries     6.833333
#             Simple Keyword Queries         6.166667
#             Thematic/Semantic Queries      5.666667
# TFIDF_GLoVe Long/Complex Queries           5.833333
#             Orthodox Service Quotes        6.000000
#             Phrase/Exact Match Queries     3.166667
#             Simple Keyword Queries         9.000000
#             Thematic/Semantic Queries      5.083333

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Pivot table
pivot = pd.pivot_table(
    scores,
    index=["Method", "Query Category"],
    values="Human Score",
    aggfunc='mean'
).reset_index()

# Unique methods
methods = pivot['Method'].unique()
n_methods = len(methods)

# Determine layout: 2 rows
n_rows = 2
n_cols = math.ceil(n_methods / n_rows)

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 5*n_rows), sharey=True)
axes = axes.flatten()  # flatten in case of 2D array

# Plot each method
for ax, method in zip(axes, methods):
    subset = pivot[pivot['Method'] == method]
    sns.barplot(
        data=subset,
        x='Query Category',
        y='Human Score',
        ax=ax,
        palette='viridis'
    )
    
    
    ax.set_title(method)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    ax.set_xlabel("Query Category")
    ax.set_ylabel("Human Score")

# Turn off any unused axes
for ax in axes[n_methods:]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Pivot table
pivot = pd.pivot_table(
    scores,
    index=["Method", "Query Category"],
    values="Human Score",
    aggfunc='mean'
).reset_index()

# Unique methods
methods = pivot['Method'].unique()
n_methods = len(methods)

# Determine layout: 2 rows
n_rows = 2
n_cols = math.ceil(n_methods / n_rows)

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 5*n_rows), sharey=True)
axes = axes.flatten()  # flatten in case of 2D array

# Plot each method
for ax, method in zip(axes, methods):
    subset = pivot[pivot['Method'] == method]
    
    # Bar plot
    sns.barplot(
        data=subset,
        x='Query Category',
        y='Human Score',
        ax=ax,
        palette='viridis'
    )
    
    # Compute overall average for this method
    method_avg = subset['Human Score'].mean()
    
    # Add horizontal line
    ax.axhline(method_avg, color='red', linestyle='--', label=f"Avg: {method_avg:.2f}")
    
    # Title and labels
    ax.set_title(method)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    ax.set_xlabel("Query Category")
    ax.set_ylabel("Human Score")
    
    # Optional: add legend for the line
    ax.legend()


# Turn off any unused axes
for ax in axes[n_methods:]:
    ax.axis('off')

plt.tight_layout()
plt.show()
